# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from scipy import ndimage,signal
import math

# %%
def fftnshift(img):
    f_img = np.fft.fft2(img)
    # Hàm fftshift đưa DC component về điểm chính giữa.
    fshift = np.fft.fftshift(f_img)
    return fshift

def invert_shiftnfft(filter_fshift):
    # Invert fftshift
    filter_fishift = np.fft.ifftshift(filter_fshift)
    # Invert FFT
    filter_img = np.fft.ifft2(filter_fishift)
    return np.abs(filter_img)

def apply_fft(img, kernel):
    # Đọc hiểu code từ https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_transforms/py_fourier_transform/py_fourier_transform.html

    # Sử dụng hàm fft2 cho ảnh 2 chiều, output là biểu diễn tần số của input,
    # giá trị ở mỗi điểm ảnh là 1 số phức biểu diễn magnitude và phase,
    # zero frequency component (hay DC component) sẽ ở góc trái trên.
    f_img = np.fft.fft2(img)

    # Hàm fftshift đưa DC component về điểm chính giữa.
    fshift = np.fft.fftshift(f_img)
    filter_fshift = fshift*kernel 
    # Invert fftshift
    filter_fishift = np.fft.ifftshift(filter_fshift)
    # Invert FFT
    filter_img = np.fft.ifft2(filter_fishift)
    return np.abs(filter_img)

# %%
def showgray(img):
    fig, ax = plt.subplots()
    ax.imshow(img, cmap='gray')
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])
    plt.show()

def show(img):
    fig, ax = plt.subplots()
    ax.imshow(img)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])
    plt.show()
    
def plotmxn(m, n, data, is_image, labels=None,  size=(10, 10)):
    if size:
        plt.figure(figsize=size)
    for i in range(len(data)):
        ax = plt.subplot(m,n,i+1)
    #     plt.grid(False)
        if is_image:
            plt.imshow(data[i])
        else:
            plt.plot(data[i][0], data[i][1])
        if labels:
            plt.xlabel(labels[i])
    plt.show()

# %%
# Các hàm sinh filter
def idea_lowpass_filter(shape, r):
    tmp = np.zeros(shape)
    center = np.array(shape) // 2
    I, J = np.ogrid[:shape[0], :shape[1]]
    return (I - center[0])**2 + (J - center[1])**2 < r**2

def butterworth_filter(shape, D0, n):
    center = np.array(shape) // 2
    I, J = np.ogrid[:shape[0], :shape[1]]
    D_uv = np.sqrt((I - center[0])**2 + (J - center[1])**2)
    return 1 / (1 + (D_uv/D0)**n)

def gaussian_filter(shape, D0):
    center = np.array(shape) // 2
    I, J = np.ogrid[:shape[0], :shape[1]]
    D_uv_sq = (I - center[0])**2 + (J - center[1])**2
    return np.exp(-D_uv_sq/(2*(D0**2)))/(2*D0**2*math.pi)

# %%
img = cv2.imread('ntest.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
show(img)

# %% [markdown]
# # Remove high-frequency noise and suppress the blur
#
# Before calculating spectrum contrast, a Gaussian filter
# with small kernel is applied to the original image to re-
# move high-frequency noise and suppress the blur caused
# by blur texture (e.g., soft shadows or blur patterns). The
# Gaussian filter is given by
# set the Gaussian kernel $σ_1$ to 0.5 in our experiment.

# %%
sigma1 = 0.5
pregf = gaussian_filter((3,3), sigma1)
pregf = np.repeat(pregf[..., None],3,axis=2)
showgray(pregf[...,2])

# %%
preimg = np.empty(img.shape)
preimg[..., 0] = ndimage.convolve(img[..., 0], pregf[..., 0], mode='nearest')
preimg[..., 1] = ndimage.convolve(img[..., 1], pregf[..., 0], mode='nearest')
preimg[..., 2] = ndimage.convolve(img[..., 2], pregf[..., 0], mode='nearest')

show(preimg/255);

# %%
plt.hist(preimg[..., 2].flat);

# %% [markdown]
# Note that we only calculate the spectrum contrast at edge locations, we use Canny edge detector [13]to
# perform our edge detection on the input image. According to the refraction regularity, chromatic aberrations are
# caused by the refractive index of the lens being wave-length-dependent. This causes that color channels of
# an RGB color image will appear shifted. More detailed discussion of these artif acts can be found in the paper
# by Kang [14]. One can convert the image to gray scale for edge detection but it is not accurate. In order to re-
# duce the error of edge detection, we perform edge detection on each color channel independently and only keep
# edges that are detected within five pixels of each other in channel R, G, and B.

# %%
edges = np.empty(img.shape)
edges[..., 0] = cv2.Canny(np.uint8(preimg[...,0]),100,180)
edges[..., 1] = cv2.Canny(np.uint8(preimg[...,1]),100,180)
edges[..., 2] = cv2.Canny(np.uint8(preimg[...,2]),100,180)
plotmxn(2, 2, np.transpose(edges, axes=[2, 0, 1]), True)

# %% [markdown]
# # In the Fourier domain

# %%
F = fftnshift(preimg)
#  = fftnshift(preimg)
N = 3
kernel = np.ones((N, N))
kernel[N//2, N//2] = 0
kernel = -kernel/(N**2)
C = np.empty(F.shape)
c = np.empty(F.shape)
for i in range(F.shape[-1]):
    C[..., i] = np.log(np.abs(F[..., i])) - np.log(np.abs(signal.convolve2d(F[...,i], kernel, mode='same')))
    c[..., i] = invert_shiftnfft(C[...,i])
sigma = 1/np.sqrt(np.exp(c) - sigma1**2)

# %%
sparse = sigma.copy()
sparse[edges == 0] = 0

# %%
# s = cv2.cvtColor(sparse, cv2.COLOR_RGB2GRAY)
show(sparse)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.hist(sparse.flat)
# Out:
# (array([85857.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#             0.,  8751.]),
#  array([0.        , 0.11546825, 0.23093649, 0.34640474, 0.46187299,
#         0.57734123, 0.69280948, 0.80827772, 0.92374597, 1.03921422,
#         1.15468246]),
#  <BarContainer object of 10 artists>)

# %%
# !conda install -y scikit-learn

# %%
import mattinglaplacian
from sklearn.preprocessing import normalize
import importlib

# %%
importlib.reload(mattinglaplacian)
mL = mattinglaplacian.matting_laplacian

# %%
nsparse.shape
# Out:
# (512, 512)

# %%
nsparse = (sparse[..., 0] - sparse[..., 0].min())/sparse[..., 0].max()

nimg = preimg/255
# nimg[..., 0] = normalize(preimg[...,0])
# nimg[..., 1] = normalize(preimg[...,1])
# nimg[..., 2] = normalize(preimg[...,2])

# %%
out = mL(nimg, nsparse)
# Out:
# d
# generating matting laplacian 1 / 214
# generating matting laplacian 2 / 214
# generating matting laplacian 3 / 214
# generating matting laplacian 4 / 214
# generating matting laplacian 5 / 214
# generating matting laplacian 6 / 214
# generating matting laplacian 7 / 214
# generating matting laplacian 8 / 214
# generating matting laplacian 9 / 214
# generating matting laplacian 10 / 214
# generating matting laplacian 11 / 214
# generating matting laplacian 12 / 214
# generating matting laplacian 13 / 214
# generating matting laplacian 14 / 214
# generating matting laplacian 15 / 214
# generating matting laplacian 16 / 214
# generating matting laplacian 17 / 214
# generating matting laplacian 18 / 214
# generating matting laplacian 19 / 214
# generating matting laplacian 20 / 214
# generating matting laplacian 21 / 214
# generating matting laplacian 22 / 214
# generating matting laplacian 23 / 214
# generating matting laplacian 24 / 214
# generating matting laplacian 25 / 214
# generating matting laplacian 26 / 214
# generating matting laplacian 27 / 214
# generating matting laplacian 28 / 214
# generating matting laplacian 29 / 214
# generating matting laplacian 30 / 214
# generating matting laplacian 31 / 214
# generating matting laplacian 32 / 214
# generating matting laplacian 33 / 214
# generating matting laplacian 34 / 214
# generating matting laplacian 35 / 214
# generating matting laplacian 36 / 214
# generating matting laplacian 37 / 214
# generating matting laplacian 38 / 214
# generating matting laplacian 39 / 214
# generating matting laplacian 40 / 214
# generating matting laplacian 41 / 214
# generating matting laplacian 42 / 214
# generating matting laplacian 43 / 214
# generating matting laplacian 44 / 214
# generating matting laplacian 45 / 214
# generating matting laplacian 46 / 214
# generating matting laplacian 47 / 214
# generating matting laplacian 48 / 214
# generating matting laplacian 49 / 214
# generating matting laplacian 50 / 214
# generating matting laplacian 51 / 214
# generating matting laplacian 52 / 214
# generating matting laplacian 53 / 214
# generating matting laplacian 54 / 214
# generating matting laplacian 55 / 214
# generating matting laplacian 56 / 214
# generating matting laplacian 57 / 214
# generating matting laplacian 58 / 214
# generating matting laplacian 59 / 214
# generating matting laplacian 60 / 214
# generating matting laplacian 61 / 214
# generating matting laplacian 62 / 214
# generating matting laplacian 63 / 214
# generating matting laplacian 64 / 214
# generating matting laplacian 65 / 214
# generating matting laplacian 66 / 214
# generating matting laplacian 67 / 214
# generating matting laplacian 68 / 214
# generating matting laplacian 69 / 214
# generating matting laplacian 70 / 214
# generating matting laplacian 71 / 214
# generating matting laplacian 72 / 214
# generating matting laplacian 73 / 214
# generating matting laplacian 74 / 214
# generating matting laplacian 75 / 214
# generating matting laplacian 76 / 214
# generating matting laplacian 77 / 214
# generating matting laplacian 78 / 214
# generating matting laplacian 79 / 214
# generating matting laplacian 80 / 214
# generating matting laplacian 81 / 214
# generating matting laplacian 82 / 214
# generating matting laplacian 83 / 214
# generating matting laplacian 84 / 214
# generating matting laplacian 85 / 214
# generating matting laplacian 86 / 214
# generating matting laplacian 87 / 214
# generating matting laplacian 88 / 214
# generating matting laplacian 89 / 214
# generating matting laplacian 90 / 214
# generating matting laplacian 91 / 214
# generating matting laplacian 92 / 214
# generating matting laplacian 93 / 214
# generating matting laplacian 94 / 214
# generating matting laplacian 95 / 214
# generating matting laplacian 96 / 214
# generating matting laplacian 97 / 214
# generating matting laplacian 98 / 214
# generating matting laplacian 99 / 214
# generating matting laplacian 100 / 214
# generating matting laplacian 101 / 214
# generating matting laplacian 102 / 214
# generating matting laplacian 103 / 214
# generating matting laplacian 104 / 214
# generating matting laplacian 105 / 214
# generating matting laplacian 106 / 214
# generating matting laplacian 107 / 214
# generating matting laplacian 108 / 214
# generating matting laplacian 109 / 214
# generating matting laplacian 110 / 214
# generating matting laplacian 111 / 214
# generating matting laplacian 112 / 214
# generating matting laplacian 113 / 214
# generating matting laplacian 114 / 214
# generating matting laplacian 115 / 214
# generating matting laplacian 116 / 214
# generating matting laplacian 117 / 214
# generating matting laplacian 118 / 214
# generating matting laplacian 119 / 214
# generating matting laplacian 120 / 214
# generating matting laplacian 121 / 214
# generating matting laplacian 122 / 214
# generating matting laplacian 123 / 214
# generating matting laplacian 124 / 214
# generating matting laplacian 125 / 214
# generating matting laplacian 126 / 214
# generating matting laplacian 127 / 214
# generating matting laplacian 128 / 214
# generating matting laplacian 129 / 214
# generating matting laplacian 130 / 214
# generating matting laplacian 131 / 214
# generating matting laplacian 132 / 214
# generating matting laplacian 133 / 214
# generating matting laplacian 134 / 214
# generating matting laplacian 135 / 214
# generating matting laplacian 136 / 214
# generating matting laplacian 137 / 214
# generating matting laplacian 138 / 214
# generating matting laplacian 139 / 214
# generating matting laplacian 140 / 214
# generating matting laplacian 141 / 214
# generating matting laplacian 142 / 214
# generating matting laplacian 143 / 214
# generating matting laplacian 144 / 214
# generating matting laplacian 145 / 214
# generating matting laplacian 146 / 214
# generating matting laplacian 147 / 214
# generating matting laplacian 148 / 214
# generating matting laplacian 149 / 214
# generating matting laplacian 150 / 214
# generating matting laplacian 151 / 214
# generating matting laplacian 152 / 214
# generating matting laplacian 153 / 214
# generating matting laplacian 154 / 214
# generating matting laplacian 155 / 214
# generating matting laplacian 156 / 214
# generating matting laplacian 157 / 214
# generating matting laplacian 158 / 214
# generating matting laplacian 159 / 214
# generating matting laplacian 160 / 214
# generating matting laplacian 161 / 214
# generating matting laplacian 162 / 214
# generating matting laplacian 163 / 214
# generating matting laplacian 164 / 214
# generating matting laplacian 165 / 214
# generating matting laplacian 166 / 214
# generating matting laplacian 167 / 214
# generating matting laplacian 168 / 214
# generating matting laplacian 169 / 214
# generating matting laplacian 170 / 214
# generating matting laplacian 171 / 214
# generating matting laplacian 172 / 214
# generating matting laplacian 173 / 214
# generating matting laplacian 174 / 214
# generating matting laplacian 175 / 214
# generating matting laplacian 176 / 214
# generating matting laplacian 177 / 214
# generating matting laplacian 178 / 214
# generating matting laplacian 179 / 214
# generating matting laplacian 180 / 214
# generating matting laplacian 181 / 214
# generating matting laplacian 182 / 214
# generating matting laplacian 183 / 214
# generating matting laplacian 184 / 214
# generating matting laplacian 185 / 214
# generating matting laplacian 186 / 214
# generating matting laplacian 187 / 214
# generating matting laplacian 188 / 214
# generating matting laplacian 189 / 214
# generating matting laplacian 190 / 214
# generating matting laplacian 191 / 214
# generating matting laplacian 192 / 214
# generating matting laplacian 193 / 214
# generating matting laplacian 194 / 214
# generating matting laplacian 195 / 214
# generating matting laplacian 196 / 214
# generating matting laplacian 197 / 214
# generating matting laplacian 198 / 214
# generating matting laplacian 199 / 214
# generating matting laplacian 200 / 214
# generating matting laplacian 201 / 214
# generating matting laplacian 202 / 214
# generating matting laplacian 203 / 214
# generating matting laplacian 204 / 214
# generating matting laplacian 205 / 214
# generating matting laplacian 206 / 214
# generating matting laplacian 207 / 214
# generating matting laplacian 208 / 214
# generating matting laplacian 209 / 214
# generating matting laplacian 210 / 214
# generating matting laplacian 211 / 214
# generating matting laplacian 212 / 214
# generating matting laplacian 213 / 214
# generating matting laplacian 214 / 214
# solving linear system...

# %%
plt.hist(sparse.flat);

# %%
showgray(out)

# %%
sparse[...,0].max()
# Out:
# 1.1546950450473135

# %%
plt.hist(img.flat)
# Out:
# (array([ 31150.,  30447., 106380., 148722., 126056.,  84966.,  65730.,
#          73295.,  87408.,  32278.]),
#  array([  3. ,  28.2,  53.4,  78.6, 103.8, 129. , 154.2, 179.4, 204.6,
#         229.8, 255. ]),
#  <BarContainer object of 10 artists>)
