# %%
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt
from depth.akai import *
from utils import *
from skimage import feature
from depth import pipeline
from defocus_estimation import zhuo
from skimage import color
import scipy.ndimage as sciimg
import scipy.signal as scisig
from filters.bilateral_filters import sparse_bilateral_filter
from filters.guided_filter.gf import guided_filter
from cv2.ximgproc import guidedFilter

# %%
image = readrgb_double('images/color6.jpg')
show(image)
plt.imshow(pipeline.get_bmap(image, 1), cmap='gray')
plt.imshow(pipeline.get_bmap(image, 1, guide=True), cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-c1c1060ab94b> in <module>
#       1 image = readrgb_double('images/color6.jpg')
#       2 show(image)
# ----> 3 plt.imshow(pipeline.get_bmap(image, 1), cmap='gray')
#       4 plt.imshow(pipeline.get_bmap(image, 1, guide=True), cmap='gray')
#
# ~/Courses/UET/ImgSeg/depth/pipeline.py in get_bmap(img, std, sigma_canny, max_blur, guide)
#      44     else:
#      45         guided_sparse_map = sparse_bilateral_filter(gray, img, 5, 0.1)
# ---> 46     return propagate_map(img, guided_sparse_map)
#      47
#
# ~/Courses/UET/ImgSeg/depth/pipeline.py in propagate_map(img, sparse_bmap)
#      22
#      23 def propagate_map(img, sparse_bmap):
# ---> 24     h, w = sparse_bmap.shape
#      25     L1 = get_laplacian(img)
#      26     A, b = make_system(L1, sparse_bmap.T)
#
# ...

# %%
image = readrgb_double('images/color5.png')
show(image)
plt.imshow(pipeline.get_bmap(image, 1), cmap='gray')

# %%
image = readrgb_double('images/color1.jpg')
show(image)
plt.imshow(pipeline.get_bmap(image, 1), cmap='gray')

# %%
image = readrgb_double('images/color2.jpg')
show(image)
plt.imshow(pipeline.get_bmap(image, 1), cmap='gray')
# Out:
# 0.9736725124876257

# %%
image = readrgb_double('images/color4.jpeg')
show(image)
plt.imshow(pipeline.get_bmap(image, 1), cmap='gray')
